# %%
import numpy as np

def cosine_similarity(vec_a: np.ndarray, vec_b: np.ndarray)->float:
  dot = np.dot(vec_a, vec_b)
  norm_a = np.linalg.norm(vec_a)
  norm_b = np.linalg.norm(vec_b)
  return dot / (norm_a*norm_b)

# %% [markdown]
# # openai embedding

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
openai_client = OpenAI()

# %%
def get_openai_embedding(text:str, model='text-embedding-3-small'):
  response = openai_client.embeddings.create(
    input = text, 
    model=model
  )
  return response.data[0].embedding

# %%
text_str = '안녕하세요'
emb_vector = get_openai_embedding(text_str)
len(emb_vector.embedding)
# Out:
# 1536

# %%
# 임베딩모델 생성
from langchain_upstage import UpstageEmbeddings
import os
embeddings = UpstageEmbeddings(
  api_key=os.getenv('UPSTAGE_API_KEY'),
  model='solar-embedding-1-large'
)

# %%
#업스테이지 모델로 임베딩함수
def get_upstage_embedding(text: str, is_query: bool = False) -> np.ndarray:
    if is_query:
        vec = embeddings.embed_query(text)
    else:
        vec = embeddings.embed_documents([text])[0]  # 리스트에서 첫 번째 요소만 추출
    return np.array(vec)

# %%
# pip install -qU langchain-core langchain-upstage
import os

from langchain_upstage import UpstageEmbeddings
 
embeddings = UpstageEmbeddings(
    api_key= os.getenv('UPSTAGE_API_KEY'),
    model="embedding-query"
)
 
doc_result = embeddings.embed_documents(
    ["Sam is a teacher.", "This is another document"]
)
print(doc_result)
 
query_result = embeddings.embed_query("What does Sam do?")
print(query_result)
# Out:
# [[0.016357421875, 0.0171356201171875, -0.0077972412109375, 0.024078369140625, 0.00342559814453125, -0.00682830810546875, -0.01465606689453125, -0.01067352294921875, -0.015625, 0.00673675537109375, 0.0183258056640625, 0.00507354736328125, 0.007244110107421875, 0.01177978515625, 0.02777099609375, 0.02191162109375, -0.0213623046875, -0.0012531280517578125, -0.0030117034912109375, -0.0167388916015625, -0.02410888671875, -0.0090789794921875, -0.01122283935546875, -0.005924224853515625, -0.01036834716796875, 0.0162811279296875, 0.002777099609375, -0.01197052001953125, 0.00518798828125, 0.02154541015625, 0.0056610107421875, 0.01412200927734375, 0.0020542144775390625, -0.0094146728515625, 0.01070404052734375, -0.01226806640625, -0.003635406494140625, 0.02374267578125, -0.012420654296875, 0.01287078857421875, -0.0112152099609375, -0.02001953125, -0.01410675048828125, 8.320808410644531e-05, -0.016510009765625, 0.012786865234375, 0.00691986083984375, -0.0008373260498046875, 0.004840850830078125, 0.0025005340576171875, -0.0015001296997070312, -0.0083465576171875, -0.006473541259765625, -0.09161376953125, 0.03076171875, 0.017181396484375, -0.00312042236328125, -0.016326904296875, 0.0118865966796875, 0.005199432373046875, -0.004695892333984375, 0.0110321044921875, 0.01995849609375, -0.0228118896484375, -0.004734039306640625, -0.0164947509765625, 0.004974365234375, 0.01132965087890625, -0.0035152435302734375, 0.0259552001953125, 0.0003616809844970703, -0.0027923583984375, -0.0148162841796875, 0.0239410400390625, -0.01261138916015625, -0.01152801513671875, -0.0006041526794433594, -0.01079559326171875, 0.001003265380859375, -0.0012340545654296875, 0.0037593841552734375, -0.00038504600524902344, -0.0119781494140625, 0.0105743408203125, 0.0083160400390625, 0.048736572265625, -0.007110595703125, 0.01105499267578125, -0.00418853759765625, -0.002414703369140625, -0.0225830078125, -0.03570556640625, -0.009735107421875, 0.0009765625, 0.0012426376342773438, 0.0201873779296875, 0.01311492919921875, -0.0016679763793945
823883729055524, 0.009916122071444988, 0.019776416942477226, -0.019497286528348923, -0.019902026280760765, -0.009748643264174461, 0.004654506221413612, -0.012470168061554432, -0.004884788766503334, 0.008311119861900806, 0.045526232570409775, 0.01170255895704031, 0.009043837897479534, -0.022972464561462402, 0.011388536542654037, -0.01621749997138977, 0.016077933833003044, -0.025247380137443542, 0.04011109471321106, -0.015715064480900764, 0.01170255895704031, 0.0044416687451303005, 0.00632929103448987, -0.028582993894815445, -0.015770889818668365, 0.00294831907376647, 0.00571869220584631, -0.006671226117759943, 0.0005024354322813451, -0.000496765598654747, 0.02842947281897068, 0.011521123349666595, 0.0009080473682843149, -0.00969979539513588, 0.03017403930425644, 0.006486301776021719, 0.007515596691519022, -0.026084773242473602, -0.014877671375870705, -0.031458042562007904, 0.018213285133242607, 0.013042386621236801, 0.02018115669488907, 0.006849172059446573, 0.01843659020960331, -0.020041590556502342, 0.02016719989478588, 0.00511856097728014, -0.0174875445663929, -0.008185510523617268, -0.0010868655517697334, 0.030146125704050064, 0.019888069480657578, -0.0038799180183559656, 0.010969839990139008, 0.006374649703502655, -0.014612497761845589, 0.015073062852025032, -0.003534493735060096, 0.007836597040295601, 0.017808545380830765, -0.024200640618801117, 0.0025156664196401834, -0.01230269018560648, 0.013237778097391129, -0.015994194895029068, -0.004389331676065922, -0.0014968388713896275, -0.0011801999062299728, 0.02286081202328205, 0.00903685949742794, 0.033663176000118256, -0.000738824310246855, -0.0004910957650281489, -0.00398110318928957, 0.009169447235763073, 0.010851209983229637, -0.012665560469031334, -0.02220485545694828, -0.008115728385746479, -0.02340511791408062, -0.029476212337613106, 0.004214874934405088, 0.006552595645189285, 0.0049022347666323185, 0.02323763817548752, 0.0018684318056330085, 0.01137457974255085, -0.0019347253255546093, -0.015840671956539154, 0.005715203005820513, 0.005436072126030922, -0.012079385109245777, -0.004549832083284855, 0.01998576521873474, -0.0029954223427921534, -0.013635539449751377, 0.00703409593552351, 0.022832900285720825, -0.019846199080348015, -0.0044626034796237946, 0.0009124088101089001, 0.004567277617752552, 0.01371927838 ...

# %%
len(query_result)
# Out:
# 4096

# %% [markdown]
# #openai embedding 모델로 임베딩

# %%
texts = ['king', 'queen', 'slave', '왕']

# %%
openai_embeddings = {txt: get_openai_embedding(txt) for txt in texts}

# %%
cosine_similarity(openai_embeddings['queen'], openai_embeddings['king'])
# Out:
# np.float64(0.5906015302396912)

# %% [markdown]
# #업스테이 임베딩 모델로 임베딩

# %%
upstage_embeddings = {txt: get_upstage_embedding(txt) for txt in texts}

# %%
cosine_similarity(upstage_embeddings['queen'], upstage_embeddings['king'])
# Out:
# np.float64(0.6445563269944867)

# %% [markdown]
# # 왕의 비교

# %%
cosine_similarity(openai_embeddings['왕'], openai_embeddings['king'])
# Out:
# np.float64(0.5040406331683573)

# %%
cosine_similarity(upstage_embeddings['왕'], upstage_embeddings['king'])
# Out:
# np.float64(0.6961081410307075)

# %% [markdown]
# 젬마2 모델로 임베딩 비교

# %% [markdown]
# # 올라마 임베딩 > huggingface 의 임베딩 모델

# %%
# !pip install sentence-transformers

# %%
from langchain_community.chat_models import ChatOllama
llm_ollama = ChatOllama(model='gemma2')
response = llm_ollama.invoke('안녕? 네 소개를 2줄로 작성해')
response.content

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('BAAI/bge-multilingual-gemma2')
gemma_embedding = model.encode(texts)
gemma_embedding
